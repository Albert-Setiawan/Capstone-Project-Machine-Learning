# %%
import tensorflow as tf
import numpy as np
import os
import random
from shutil import copyfile
from keras.preprocessing.image import ImageDataGenerator
import tensorflow_hub as hub
from tensorflow import keras
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
session.close()

# %%
root_path='D:\Bangkit 2022\SKUT\Dataset_2'
#os.makedirs(os.path.join(root_path,'train'))
#os.makedirs(os.path.join(root_path,'test'))

dir_path=['Acne','Cancer','Eksim','Rosacea','Normal']
train_dir='D:\Bangkit2022\SKUT\Dataset_2/train/'
test_dir='D:\Bangkit2022\SKUT\Dataset_2/test/'

# %%
#make folder inside the train and test
for dir in dir_path:
   os.makedirs(os.path.join(test_dir,dir))
   os.makedirs(os.path.join(train_dir,dir))

# %%
def splitData(source,train_dir,test_dir,split_size):
    files=[]
    for filename in os.listdir(source):
      file=source+'/'+filename
      if os.path.getsize(file)>0:
        files.append(filename)
      else:
        print(filename+" is zero length")
    training_length=int(len(files)*split_size)
    testing_length=int(len(files)-training_length)
    shuffled_set=random.sample(files, len(files))
    training_set=shuffled_set[:training_length]
    testing_set=shuffled_set[training_length:]

    for filename in training_set:
      this_file=source+'/'+filename
      destination=train_dir+filename
      copyfile(this_file,destination)
    for filename in testing_set:
      this_file=source+'/'+filename
      destination=test_dir+filename
      copyfile(this_file,destination)
    pass

# %%
def dropImage(dir):
  for item in os.listdir(dir):
    path=os.path.join(dir,item)
    for file in os.listdir(path):
      sub_path=os.path.join(path,file)
      with Image.open(sub_path) as image:
            x, y = image.size
      if x<180 or y<180:
        print("Delete :"+sub_path)
        os.remove(sub_path)
dropImage(root_path+"/Dataset")

# %%
#Split dataset and copy into different folder
for dir in dir_path:
  splitData(root_path+'/Dataset - Copy/'+dir,train_dir+'/'+dir+'/',test_dir+'/'+dir+'/',.5)

# %%
#Create ImageDataGenerator
def training_testing_generator(training_dir,testing_dir):
  train_datagen=ImageDataGenerator(
      rotation_range=10,
       zoom_range=0.4,
       horizontal_flip=True,
       rescale=1/255,
       brightness_range=[0.4,1.5],
       width_shift_range=0.1,
       height_shift_range=0.1,
       fill_mode='nearest'
  )
  valid_datagen=ImageDataGenerator(rescale=1.0/255.0)
  train_generator=train_datagen.flow_from_directory(training_dir,batch_size=32,class_mode='categorical',target_size=(180,180))
  valid_generator=valid_datagen.flow_from_directory(testing_dir,batch_size=16,class_mode='categorical',target_size=(180,180))
  return train_generator,valid_generator

# %%
#Make the generator
train_generator, validation_generator = training_testing_generator(train_dir, test_dir)
# Out:
# Found 625 images belonging to 5 classes.
# Found 625 images belonging to 5 classes.

# %%
def make_model():
    from tensorflow.keras.applications.inception_v3 import InceptionV3
    model=tf.keras.models.Sequential([
        tf.keras.applications.InceptionV3(include_top=False,input_shape=(180,180,3),),
        #tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(180,180,3)),
        #tf.keras.layers.MaxPool2D(2,2),
        #tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
        #tf.keras.layers.MaxPool2D(2,2),
        #tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
        #tf.keras.layers.MaxPool2D(2,2),
        #tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
        #tf.keras.layers.MaxPool2D(2,2),
        #tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
        #tf.keras.layers.MaxPool2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(5,activation='softmax')
    ])
    model.summary()
    return model

# %%
#Make model
model=make_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),loss='categorical_crossentropy',metrics=['accuracy'])
history=model.fit(train_generator,epochs=100,verbose=1,validation_data=validation_generator)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 4, 4, 2048)        21802784
#
#  flatten (Flatten)           (None, 32768)             0
#
#  batch_normalization_94 (Bat  (None, 32768)            131072
#  chNormalization)
#
#  dropout (Dropout)           (None, 32768)             0
#
#  dense (Dense)               (None, 64)                2097216
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 24,031,397
# Trainable params: 23,931,429
# Non-trainable params: 99,968
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 38s 1s/step - loss: 3.2872 - accuracy: 0.4960 - val_loss: 1593.5991 - val_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 9s 419ms/step - loss: 4.7241 - accuracy: 0.4784 - val_loss: 129787360.0000 - val_accuracy: 0.2000
# Epoch 3/100
# 20/20 [==============================] - 8s 412ms/step - loss: 7.8936 - accuracy: 0.3296 - val_loss: 40330.5938 - val_accuracy: 0.2240
# Epoch 4/100
# 20/20 [==============================] - 8s 414ms/step - loss: 3.6601 - accuracy: 0.2944 - val_loss: 37680181248.0000 - val_accuracy: 0.2000
# Epoch 5/100
# 20/20 [==============================] - 8s 408ms/step - loss: 2.6887 - accuracy: 0.2080 - val_loss: 2295375.5000 - val_accuracy: 0.2000
# Epoch 6/100
# 20/20 [==============================] - 9s 421ms/step - loss: 2.1572 - accuracy: 0.2288 - val_loss: 16958192.0000 - val_accuracy: 0.1984
# Epoch 7/100
# 20/20 [==============================] - 8s 405ms/step - loss: 2.0467 - accuracy: 0.2048 - val_loss: 123850.2109 - val_accuracy: 0.1952
# Epoch 8/100
# 20/20 [==============================] - 8s 411ms/step - loss: 1.9715 - accuracy: 0.1904 - val_loss: 3407.4536 - val_accuracy: 0.2016
# Epoch 9/100
# 20/20 [==============================] - 8s 409ms/step - loss: 1.6816 - accuracy: 0.2128 - val_loss: 2374.9673 - val_accuracy: 0.2048
# Epoch 10/100
# 20/20 [==============================] - 8s 411ms/step - loss: 1.6988 - accuracy: 0.1680 - val_loss: 2099.3147 - val_accuracy: 0.2064
# Epoch 11/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.6231 - accuracy: 0.2160 - val_loss: 1123.2007 - val_accuracy: 0.1760
# Epoch 12/100
# 20/20 [==============================] - 8s 412ms/step - loss: 1.5932 - accuracy: 0.2368 - val_loss: 247.4538 - val_accuracy: 0.1776
# Epoch 13/100
# 20/20 [==============================] - 9s 422ms/step - loss: 1.5622 - accuracy: 0.2768 - val_loss: 50.9221 - val_accuracy: 0.2480
# Epoch 14/100
# 20/20 [==============================] - 8s 409ms/step - loss: 1.4588 - accuracy: 0.3360 - val_loss: 14.2526 - val_accuracy: 0.2080
# Epoch 15/100
# 20/20 [==============================] - 8s 407ms/step - loss: 1.3572 - accuracy: 0.3680 - val_loss: 11.9767 - val_accuracy: 0.2128
# Epoch 16/100
# 20/20 [==============================] - 8s 411ms/step - loss: 1.2795 - accuracy: 0.3936 - val_loss: 10.4434 - val_accuracy: 0.1888
# Epoch 17/100
# 20/20 [==============================] - 8s 414ms/step - loss: 1.2617 - accuracy: 0.4304 - val_loss: 4.0152 - val_accuracy: 0.1984
# Epoch 18/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.1984 - accuracy: 0.4496 - val_loss: 3.0258 - val_accuracy: 0.2080
# Epoch 19/100
# 20/20 [==============================] - 8s 411ms/step - loss: 1.2394 - accuracy: 0.4512 - val_loss: 3.0179 - val_accuracy: 0.2016
# Epoch 20/100
# 20/20 [==============================] - 8s 426ms/step - loss: 1.2302 - accuracy: 0.4704 - val_loss: 165.9229 - val_accuracy: 0.2416
# Epoch 21/100
# 20/20 [==============================] - 9s 425ms/step - loss: 1.1678 - accuracy: 0.4720 - val_loss: 20.4918 - val_accuracy: 0.2752
# Epoch 22/100
# 20/20 [==============================] - 8s 428ms/step - loss: 1.1389 - accuracy: 0.5168 - val_loss: 3.9454 - val_accuracy: 0.1952
# Epoch 23/100
# 20/20 [==============================] - 9s 422ms/step - loss: 1.1099 - accuracy: 0.5216 - val_loss: 1.8911 - val_accuracy: 0.3120
# Epoch 24/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.1473 - accuracy: 0.5088 - val_loss: 1.5398 - val_accuracy: 0.2480
# Epoch 25/100
# 20/20 [==============================] - 8s 417ms/step - loss: 1.1193 - accuracy: 0.5232 - val_loss: 1.3081 - val_accuracy: 0.4624
# Epoch 26/100
# 20/20 [==============================] - 9s 420ms/step - loss: 1.0562 - accuracy: 0.5488 - val_loss: 1.3235 - val_accuracy: 0.4624
# Epoch 27/100
# 20/20 [==============================] - 9s 426ms/step - loss: 1.0505 - accuracy: 0.5568 - val_loss: 1.1648 - val_accuracy: 0.5520
# Epoch 28/100
# 20/20 [==============================] - 9s 422ms/step - loss: 1.0784 - accuracy: 0.5360 - val_loss: 1.1106 - val_accuracy: 0.5488
# Epoch 29/100
# 20/20 [==============================] - 8s 418ms/step - loss: 1.0188 - accuracy: 0.5728 - val_loss: 1.2695 - val_accuracy: 0.5232
# Epoch 30/100
# 20/20 [==============================] - 8s 415ms/step - loss: 0.9853 - accuracy: 0.5648 - val_loss: 2.7651 - val_accuracy: 0.5568
# Epoch 31/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.9675 - accuracy: 0.5920 - val_loss: 4.0655 - val_accuracy: 0.5488
# Epoch 32/100
# 20/20 [==============================] - 9s 421ms/step - loss: 0.9534 - accuracy: 0.5920 - val_loss: 1.4416 - val_accuracy: 0.5824
# Epoch 33/100
# 20/20 [==============================] - 8s 417ms/step - loss: 0.9454 - accuracy: 0.5904 - val_loss: 1.0004 - val_accuracy: 0.6304
# Epoch 34/100
# 20/20 [==============================] - 9s 423ms/step - loss: 0.8904 - accuracy: 0.6144 - val_loss: 0.8814 - val_accuracy: 0.6176
# Epoch 35/100
# 20/20 [==============================] - 9s 425ms/step - loss: 0.8834 - accuracy: 0.6336 - val_loss: 0.8682 - val_accuracy: 0.6400
# Epoch 36/100
# 20/20 [==============================] - 9s 427ms/step - loss: 0.8874 - accuracy: 0.6272 - val_loss: 0.9143 - val_accuracy: 0.5568
# Epoch 37/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.8917 - accuracy: 0.6192 - val_loss: 0.8515 - val_accuracy: 0.6320
100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.6027 - accuracy: 0.7504 - val_loss: 10.2233 - val_accuracy: 0.6688
# Epoch 82/100
# 20/20 [==============================] - 9s 431ms/step - loss: 0.6017 - accuracy: 0.7440 - val_loss: 41.0261 - val_accuracy: 0.6272
# Epoch 83/100
# 20/20 [==============================] - 9s 428ms/step - loss: 0.6051 - accuracy: 0.7488 - val_loss: 42.6359 - val_accuracy: 0.6480
# Epoch 84/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.6270 - accuracy: 0.7360 - val_loss: 44.7087 - val_accuracy: 0.6496
# Epoch 85/100
# 20/20 [==============================] - 9s 431ms/step - loss: 0.5681 - accuracy: 0.7552 - val_loss: 37.9121 - val_accuracy: 0.6976
# Epoch 86/100
# 20/20 [==============================] - 9s 435ms/step - loss: 0.5746 - accuracy: 0.7728 - val_loss: 5.8076 - val_accuracy: 0.6704
# Epoch 87/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.6111 - accuracy: 0.7696 - val_loss: 6.8952 - val_accuracy: 0.7056
# Epoch 88/100
# 20/20 [==============================] - 9s 434ms/step - loss: 0.5274 - accuracy: 0.7712 - val_loss: 2.5169 - val_accuracy: 0.6608
# Epoch 89/100
# 20/20 [==============================] - 9s 442ms/step - loss: 0.5848 - accuracy: 0.7648 - val_loss: 8.1281 - val_accuracy: 0.7264
# Epoch 90/100
# 20/20 [==============================] - 9s 434ms/step - loss: 0.5388 - accuracy: 0.7776 - val_loss: 22.4163 - val_accuracy: 0.7792
# Epoch 91/100
# 20/20 [==============================] - 9s 437ms/step - loss: 0.5722 - accuracy: 0.7632 - val_loss: 0.9873 - val_accuracy: 0.7456
# Epoch 92/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.6113 - accuracy: 0.7728 - val_loss: 37.3680 - val_accuracy: 0.7216
# Epoch 93/100
# 20/20 [==============================] - 9s 441ms/step - loss: 0.5495 - accuracy: 0.7680 - val_loss: 142.8756 - val_accuracy: 0.7104
# Epoch 94/100
# 20/20 [==============================] - 9s 434ms/step - loss: 0.5502 - accuracy: 0.8144 - val_loss: 155.8112 - val_accuracy: 0.6752
# Epoch 95/100
# 20/20 [==============================] - 9s 450ms/step - loss: 0.5649 - accuracy: 0.7712 - val_loss: 198.3140 - val_accuracy: 0.7040
# Epoch 96/100
# 20/20 [==============================] - 9s 439ms/step - loss: 0.6262 - accuracy: 0.7616 - val_loss: 202.9763 - val_accuracy: 0.6240
# Epoch 97/100
# 20/20 [==============================] - 9s 446ms/step - loss: 0.6533 - accuracy: 0.7280 - val_loss: 277.3617 - val_accuracy: 0.6560
# Epoch 98/100
# 20/20 [==============================] - 9s 441ms/step - loss: 0.5549 - accuracy: 0.7856 - val_loss: 201.9148 - val_accuracy: 0.6864
# Epoch 99/100
# 20/20 [==============================] - 9s 440ms/step - loss: 0.5565 - accuracy: 0.7680 - val_loss: 115.6154 - val_accuracy: 0.7120
# Epoch 100/100
# 20/20 [==============================] - 9s 434ms/step - loss: 0.5363 - accuracy: 0.7888 - val_loss: 32.2416 - val_accuracy: 0.7264

# %%
# Plot the results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs = range(len(acc))

fig = plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy ')
plt.legend(loc=0)

plt.subplot(1,2,2)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
#Predict model
import cv2
np_image = cv2.imread('D:\Bangkit2022/testing2.jfif')
np_image = np.array(np_image).astype('float32')/255
np_image = tf.image.resize(np_image, (180, 180))
np_image = np.expand_dims(np_image, axis=0)
predicted=model.predict(np_image)
print(predicted)
label = predicted.argmax(axis=-1)
print(label)
# Out:
# [[0.02888025 0.04455371 0.674353   0.0022355  0.24997759]]
# [2]

# %%
np_image
# Out:
# array([[[[7.0343137e-01, 4.7598040e-01, 1.5196078e-02],
#          [6.6764706e-01, 4.4411767e-01, 7.3529412e-03],
#          [6.3725495e-01, 4.2156863e-01, 0.0000000e+00],
#          ...,
#          [7.0343137e-01, 4.8529410e-01, 2.1078432e-02],
#          [7.0490199e-01, 4.8284313e-01, 3.2843139e-02],
#          [6.8039215e-01, 4.5686275e-01, 0.0000000e+00]],
#
#         [[6.7990196e-01, 4.4558823e-01, 1.0294118e-02],
#          [6.6960788e-01, 4.3529412e-01, 1.6176471e-02],
#          [6.6617650e-01, 4.3872550e-01, 0.0000000e+00],
#          ...,
#          [6.9754905e-01, 4.7352940e-01, 2.0098040e-02],
#          [6.7843139e-01, 4.5833334e-01, 4.4117649e-03],
#          [6.5441179e-01, 4.2254901e-01, 3.4313726e-03]],
#
#         [[6.4656866e-01, 4.0735295e-01, 0.0000000e+00],
#          [6.4754903e-01, 3.9656863e-01, 4.9019611e-04],
#          [6.2254906e-01, 3.8676471e-01, 0.0000000e+00],
#          ...,
#          [6.8186277e-01, 4.5343137e-01, 3.4313726e-03],
#          [6.5245098e-01, 4.4019610e-01, 3.4313726e-03],
#          [7.1911764e-01, 5.0196081e-01, 2.7941177e-02]],
#
#         ...,
#
#         [[6.1078435e-01, 7.6029414e-01, 9.7598040e-01],
#          [5.6813729e-01, 7.2254902e-01, 9.2990196e-01],
#          [5.8333337e-01, 7.3725492e-01, 9.2549020e-01],
#          ...,
#          [3.0441177e-01, 2.0980392e-01, 1.4705883e-02],
#          [2.9558825e-01, 2.1715686e-01, 0.0000000e+00],
#          [2.3480393e-01, 1.5539217e-01, 9.8039221e-04]],
#
#         [[6.1519611e-01, 7.6421571e-01, 9.7941178e-01],
#          [5.3676474e-01, 6.9068629e-01, 8.9950979e-01],
#          [6.4019608e-01, 7.9852945e-01, 9.8627448e-01],
#          ...,
#          [2.7205884e-01, 1.7009804e-01, 0.0000000e+00],
#          [2.9607844e-01, 2.0980392e-01, 0.0000000e+00],
#          [3.7647060e-01, 2.9313725e-01, 6.8137258e-02]],
#
#         [[5.6568629e-01, 7.2647059e-01, 9.4215685e-01],
#          [6.0784316e-01, 7.6960784e-01, 9.6715689e-01],
#          [5.8578432e-01, 7.3872548e-01, 9.4656861e-01],
#          ...,
#          [3.4215689e-01, 2.6617649e-01, 1.4705882e-02],
#          [3.0049020e-01, 2.0637256e-01, 6.3725496e-03],
#          [2.8137255e-01, 1.9215687e-01, 5.8823535e-03]]]], dtype=float32)

# %%
import tensorflowjs as tfjs
tfjs.converters.save_keras_model(model,'model_json')

# %%
from tensorflow import keras
model.save('Model_Testing/skut_model')
# Out:
# INFO:tensorflow:Assets written to: Model_Testing/skut_model\assets
